# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# let us drop the column _c39

# %%
 df.drop(columns='_c39', inplace=True)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Now I shall convert and extract the date from policy_bind_date column

# %%
df['date']=pd.to_datetime(df['policy_bind_date']) 

df['year']= df['date'].dt.year
df['month']= df['date'].dt.month
df['day']= df['date'].dt.day
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df['incident_date']=pd.to_datetime(df['incident_date']) 

df['incident_year']= df['incident_date'].dt.year
df['incident_month']= df['incident_date'].dt.month
df['incident_day']= df['incident_date'].dt.day
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.drop(columns='date', inplace=True)

# %%
df.drop(columns='incident_date', inplace=True)

# %%
df.drop(columns='policy_bind_date', inplace=True)

# %% [markdown]
# # EDA

# %%
columns=df.columns

# %%
columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', 'year', 'month', 'day',
#        'incident_year', 'incident_month', 'incident_day'],
#       dtype='object')

# %%
cols= ['months_as_customer', 'age', 'policy_number', 
      'policy_deductable', 'policy_annual_premium',
       'umbrella_limit', 'insured_zip', 
        'capital-gains', 'capital-loss',
               'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'bodily_injuries',
       'witnesses', 'total_claim_amount',
       'injury_claim', 'property_claim', 'vehicle_claim', 
        'auto_year', 'year', 'month', 'day']

# %%
for i in cols:
    sns.distplot(df[i])
    plt.show()

# %%
pd.set_option('display.max_columns', 100)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_state policy_csl  \
# 0                   328   48         521585           OH    250/500
# 1                   228   42         342868           IN    250/500
# 2                   134   29         687698           OH    100/300
# 3                   256   41         227811           IL    250/500
# 4                   228   44         367455           IL   500/1000
# ..                  ...  ...            ...          ...        ...
# 995                   3   38         941851           OH   500/1000
# 996                 285   41         186934           IL    100/300
# 997                 130   34         918516           OH    250/500
# 998                 458   62         533940           IL   500/1000
# 999                 456   60         556080           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
corr_hmap=df.corr()

plt.figure(figsize=(24,24))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
# Let us find out which feature has high correlation(>0.7)

for a in range(len(df.corr().columns)):
    for b in range(a):
        if abs(df.corr().iloc[a,b]) >0.7:
            name = df.corr().columns[a]
            print(name)
# Out:
# age
# injury_claim
# property_claim
# vehicle_claim
# vehicle_claim
# vehicle_claim

# %%
#Let us now use the label encoder to transform categorical features

object=['policy_state', 'insured_sex','insured_education_level','insured_occupation','insured_hobbies','insured_relationship',
         'incident_type','collision_type','incident_severity','authorities_contacted','incident_state','incident_city',
         'incident_location', 'property_damage','police_report_available','auto_make','auto_model','fraud_reported'
         ]


from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in object:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_state policy_csl  \
# 0                   328   48         521585             2    250/500
# 1                   228   42         342868             1    250/500
# 2                   134   29         687698             2    100/300
# 3                   256   41         227811             0    250/500
# 4                   228   44         367455             0   500/1000
# ..                  ...  ...            ...           ...        ...
# 995                   3   38         941851             2   500/1000
# 996                 285   41         186934             0    100/300
# 997                 130   34         918516             2    250/500
# 998                 458   62         533940             0   500/1000
# 999                 456   60         556080             2    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
#from fastnumbers import fast_real
for val in df['policy_csl']:
   
    val = float(val.replace('/', /''))
#   val= int(val[0:2]/val[4:6])

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_state policy_csl  \
# 0                   328   48         521585             2    250/500
# 1                   228   42         342868             1    250/500
# 2                   134   29         687698             2    100/300
# 3                   256   41         227811             0    250/500
# 4                   228   44         367455             0   500/1000
# ..                  ...  ...            ...           ...        ...
# 995                   3   38         941851             2   500/1000
# 996                 285   41         186934             0    100/300
# 997                 130   34         918516             2    250/500
# 998                 458   62         533940             0   500/1000
# 999                 456   60         556080             2    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
df['policy_csl'].nunique()
# Out:
# 3

# %%
df.loc[(df["policy_csl"] =='250/500') | (df['policy_csl']=='500/1000'), 'policy_csl']=0.5

# %% [markdown]
# df.loc[(df["policy_csl"] == '100/300'), 'policy_csl']=0.3333

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_state policy_csl  \
# 0                   328   48         521585             2        0.5
# 1                   228   42         342868             1        0.5
# 2                   134   29         687698             2     0.3333
# 3                   256   41         227811             0        0.5
# 4                   228   44         367455             0        0.5
# ..                  ...  ...            ...           ...        ...
# 995                   3   38         941851             2        0.5
# 996                 285   41         186934             0     0.3333
# 997                 130   34         918516             2        0.5
# 998                 458   62         533940             0        0.5
# 999                 456   60         556080             2        0.5
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_number                  0.038991
# policy_state                  -0.026177
# policy_csl                    -0.634536
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_hobbies               -0.061563
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.193345
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_location              0.000000
# ...

# %%
# Let us make a copy of the dataframe before proceeding further to remove skewness

df_new=df.copy()
df_new
# Out:
#      months_as_customer  age  policy_number  policy_state policy_csl  \
# 0                   328   48         521585             2        0.5
# 1                   228   42         342868             1        0.5
# 2                   134   29         687698             2     0.3333
# 3                   256   41         227811             0        0.5
# 4                   228   44         367455             0        0.5
# ..                  ...  ...            ...           ...        ...
# 995                   3   38         941851             2        0.5
# 996                 285   41         186934             0     0.3333
# 997                 130   34         918516             2        0.5
# 998                 458   62         533940             0        0.5
# 999                 456   60         556080             2        0.5
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %% [markdown]
# Now we shall only choose those columns on which we need to perform power transformation

# %%
df_new = df_new[['incident_month', 'fraud_reported','vehicle_claim','insured_zip','umbrella_limit','policy_csl']]
df_new
# Out:
#      incident_month  fraud_reported  vehicle_claim  insured_zip  \
# 0                 1               1          52080       466132
# 1                 1               1           3510       468176
# 2                 2               0          23100       430632
# 3                10               1          50720       608117
# 4                 2               0           4550       610706
# ..              ...             ...            ...          ...
# 995               2               0          61040       431289
# 996               1               0          72320       608177
# 997               1               0          52500       442797
# 998               2               0          36540       441714
# 999               2               0           3680       612260
#
#      umbrella_limit policy_csl
# 0                 0        0.5
# 1           5000000        0.5
# 2           5000000     0.3333
# 3           6000000        0.5
# 4           6000000        0.5
# ...

# %%
# apllying power transform and creating the new dataframe df2
from sklearn.preprocessing import power_transform
df2=power_transform(df_new)

# %%
df2=pd.DataFrame(data=df2,columns=df_new.columns)
df2
# Out:
#      incident_month  fraud_reported  vehicle_claim   insured_zip  \
# 0         -1.100457        1.746019       0.753697 -5.551115e-16
# 1         -1.100457        1.746019      -1.786629 -4.996004e-16
# 2         -0.025412       -0.572731      -0.820881 -1.720846e-15
# 3          1.553521        1.746019       0.677602  2.164935e-15
# 4         -0.025412       -0.572731      -1.740038  2.164935e-15
# ..              ...             ...            ...           ...
# 995       -0.025412       -0.572731       1.259186 -1.720846e-15
# 996       -1.100457       -0.572731       1.904757  2.164935e-15
# 997       -1.100457       -0.572731       0.777232 -1.276756e-15
# 998       -0.025412       -0.572731      -0.104258 -1.276756e-15
# 999       -0.025412       -0.572731      -1.779087  2.164935e-15
#
#      umbrella_limit  policy_csl
# 0         -0.349113    0.732187
# 1          1.357817    0.732187
# 2          1.357817   -1.365771
# 3          1.644005    0.732187
# ...

# %%
df2.skew()
# Out:
# incident_month    0.306468
# fraud_reported    1.175051
# vehicle_claim    -0.522718
# insured_zip       0.000000
# umbrella_limit   -7.865930
# policy_csl       -0.634536
# dtype: float64

# %%
col_skewd = ['incident_month', 'fraud_reported','vehicle_claim','insured_zip','umbrella_limit']
for i in col_skewd:
    if df.skew().loc[i]>0.5:
        df[i]=np.log1p(df[i])

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_number                  0.038991
# policy_state                  -0.026177
# policy_csl                    -0.634536
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.493074
# insured_zip                    0.779710
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_hobbies               -0.061563
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.193345
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_location              0.000000
# ...

# %%
df['incident_month']=df3['incident_month']
df['fraud_reported']=df3['fraud_reported']
df['vehicle_claim']=df3['vehicle_claim']
df['insured_zip']=df3['insured_zip']
df['umbrella_limit']=df3['umbrella_limit']

# %%
#let us check for outliers
columns=df.columns

for i in columns:
    sns.boxplo
    t(df[i])
    plt.show()

# %%
from numpy import mean
from numpy import std


for i in columns:
    if isinstance(df[i][0], str) :
        continue
    else:
        #Calculating Mean and Std 
        mean, std = (df[i].mean(),df[i].std())
        # identify outliers
        cut_off = std*2.5
        lower, upper = mean - cut_off, mean + cut_off
        outliers = [x for x in df[i] if x < lower or x > upper]
        print('Identified outliers: %d' % len(outliers))
        df[i] = df[i].apply(lambda x: lower if x < lower else (upper if x > upper else x))
# Out:
# Identified outliers: 0
# Identified outliers: 8
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 13
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 2
# Identified outliers: 1
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 3
# Identified outliers: 11
# Identified outliers: 19
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# Identified outliers: 0
# ...

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.467670
# policy_number                  0.038991
# policy_state                  -0.026177
# policy_csl                    -0.634536
# policy_deductable              0.477887
# policy_annual_premium          0.016444
# umbrella_limit                 1.493074
# insured_zip                    0.779710
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_hobbies               -0.061563
# insured_relationship           0.077488
# capital-gains                  0.474158
# capital-loss                  -0.383147
# incident_type                  0.101507
# collision_type                -0.193345
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_location              0.000000
# ...

# %% [markdown]
# skewness is still not improved, let us see the correlation among features now
#
# if some of the skewed columns have multi correlation then we can remove those for good

# %%
# Let us find out which feature has high correlation(>0.7)

for a in range(len(df.corr().columns)):
    for b in range(a):
        if abs(df.corr().iloc[a,b]) >0.7:
            name = df.corr().columns[a]
            print(name)
# Out:
# age
# number_of_vehicles_involved
# injury_claim
# property_claim
# vehicle_claim
# vehicle_claim
# vehicle_claim
# incident_day

# %%
df['fraud_reported'].value_counts()
# Out:
# 0.000000    753
# 0.526589    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# The label is highly imbalanced. I shall balance it later balance it using SMOTE

# %% [markdown]
# Let us now standardize the data using standardscalar transformation & then Check Multi colinearity using VIF

# %%
from sklearn.preprocessing import StandardScaler
x = df.drop(columns=["fraud_reported"])
y=df["fraud_reported"]

scaler=StandardScaler()
x_scaled= scaler.fit_transform(x)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 1
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# ...

# %%
df['umbrella_limit'].fillna(df['umbrella_limit'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# age                            0
# policy_number                  0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# ...

# %%
df['incident_year'].value_counts()
# Out:
# 2015    1000
# Name: incident_year, dtype: int64

# %%
df.drop(columns=['incident_year'],inplace=True)

# %%
corr_hmap = df.corr()
plt.figure(figsize=(24,24))
sns.heatmap(corr_hmap, annot=True)
plt.show()

# %% [markdown]
# Age & months_as_customer are highly correlated
#
# vehicle_claim, property_claim & injury_claim are highly correlated

# %%
df.drop(columns=['months_as_customer','vehicle_claim','property_claim','injury_claim'],inplace=True)

# %% [markdown]
# Let us now proceed to build the model

# %%
from collections import Counter
Counter(df['fraud_reported'])
# Out:
# Counter({0.5265890341390445: 247, 0.0: 753})

# %% [markdown]
# # Model Fitting and Selection

# %% [markdown]
# First I shall check the best possible random state to train our model. Using LogisticRegression to check and then later will run with other models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
X=x_scaled
X=pd.DataFrame(x,columns=x.columns)
y=df['fraud_reported']

maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=i)
    mod=LogisticRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy is',maxAccu,' on Random state',maxRS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5104/4034967792.py in <module>
#       8     x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=i)
#       9     mod=LogisticRegression()
# ---> 10     mod.fit(x_train,y_train)
#      11     pred=mod.predict(x_test)
#      12     acc=accuracy_score(y_test,pred)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1136             _dtype = [np.float64, np.float32]
#    1137
# -> 1138         X, y = self._validate_data(
#    1139             X,
#    1140             y,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# ...
